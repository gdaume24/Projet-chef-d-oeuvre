# %%
import sqlalchemy as db
from functions import DataBaseV2
from sqlalchemy import create_engine
import pandas as pd
import sys
sys.path.insert(0, "..")
from stratégie_nettoyage_donnees import nettoyage_df

# %%
# Création d'une base de données
database = DataBaseV2(db_name='db', db_type='sqlite')

# %%
engine = create_engine('sqlite:///db.db', echo=False)

# %%
df = pd.read_csv("..\data\survey.csv")
df = nettoyage_df(df)
df
# Out:
# d:\Documents\Ecole\Rendus_Ecole_Simplon\PCO\E1\nouveau_projet_perso\code\Base-de-Donnee\..\stratégie_nettoyage_donnees.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["self_employed"].fillna("Other", inplace=True)
# d:\Documents\Ecole\Rendus_Ecole_Simplon\PCO\E1\nouveau_projet_perso\code\Base-de-Donnee\..\stratégie_nettoyage_donnees.py:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
database.delete_table('questionnaires')
df.to_sql('questionnaires', con=engine, if_exists='fail')
# Out:
# Table questionnaires deleted successfully
# 1254
